# %% [markdown]
# # Nettoyage des données
# Validation basique des types et des valeurs manquantes.

# %%
import pandas as pd
df = pd.read_csv('../data/raw/sample_properties.csv')
df.isna().sum()

# %%
df = df.drop_duplicates()
df.to_csv('../data/processed/properties_clean.csv', index=False)
