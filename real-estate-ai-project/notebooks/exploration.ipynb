# %% [markdown]
# # Exploration des données immobilières
# Chargement et aperçu du dataset brut.

# %%
import pandas as pd
df = pd.read_csv('../data/raw/sample_properties.csv')
df.head()

# %%
df.describe(include='all')
